# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("IBUS-620-Group-4-GPA-Survey_December-5-2017_16.28.csv")

# %%
df.head()
# Out:
#    Variable Name  Age   GPA  Units  Internationalstudent  Nearcampus  \
# 0              1    1  3.50   12.0                   2.0           2
# 1              2    5  3.50    0.0                   2.0           2
# 2              3    1  3.00   15.0                   2.0           1
# 3              4    2  3.00   15.0                   2.0           2
# 4              5    1  2.76   15.0                   2.0           2
#
#    Commutetime  Seatposition  Classsizepreference  Participationinsmallclass  \
# 0            4             3                    3                          4
# 1            3             3                    3                          3
# 2            4             4                    2                          4
# 3            4             2                    3                          2
# 4            3             1                    2                          3
#
#    Participationinlargeclass  Participationwhenbackseat  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
# Variable Name                             122 non-null int64
# Age                                       122 non-null int64
# GPA                                       119 non-null float64
# Units                                     120 non-null float64
# Internationalstudent                      121 non-null float64
# Nearcampus                                122 non-null int64
# Commutetime                               122 non-null int64
# Seatposition                              122 non-null int64
# Classsizepreference                       122 non-null int64
# Participationinsmallclass                 122 non-null int64
# Participationinlargeclass                 121 non-null float64
# Participationwhenbackseat                 122 non-null int64
# Participationwhenfrontseat                118 non-null float64
# ...

# %%
df_gpa = df["GPA"]

# %%
df_seatPosition = df["Seatposition"]

# %%
df_gpa_seatPosition = pd.concat([df_gpa, df_seatPosition], axis=1)

# %%
df_gpa_seatPosition.head()
# Out:
#     GPA  Seatposition
# 0  3.50             3
# 1  3.50             3
# 2  3.00             4
# 3  3.00             2
# 4  2.76             1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load the data
# df_gpa_seatPosition_reg = sns.load_dataset("IBUS-620-Group-4-GPA-Survey_December-5-2017_16.28.csv")
# df_gpa_seatPosition_reg = sns.load_dataset(df)

# background color = white
sns.set_style("whitegrid")
 
# output
# sns.lmplot(x="Seatposition", y="GPA", data=df_gpa_seatPosition_reg)
sns.lmplot(x="Seatposition", y="GPA", data=df)

filename = "output.png"
plt.savefig(filename)

# %%
# background color = white
sns.set(style="white", color_codes=True)
 
# output
sns.jointplot(x="Seatposition", y="GPA", data=df)
filename = "output1.png"
plt.savefig(filename)

# %%
sns.lmplot(x="Seatposition", y="GPA", hue="Internationalstudent", data=df)
# 1.0 means "international student" 2.0 means "SFSU students"
filename = "output2.png"
plt.savefig(filename)

# %%
sns.countplot(x="Seatposition", hue="Internationalstudent",data=df)
# 1.0 means "international student" 2.0 means "SFSU students"
filename = "output3.png"
plt.savefig(filename)

# %%
sns.lmplot(x="Commutetime", y="GPA", data=df)
# 4-near 1-far from the university
filename = "output4.png"
plt.savefig(filename)

# %%
sns.lmplot(x="Internationalstudenteffect", y="GPA", data=df)
filename = "output5.png"
plt.savefig(filename)

# %%
sns.lmplot(x="Classsizepreference", y="GPA", data=df)
filename = "output6.png"
plt.savefig(filename)

# %%
sns.jointplot(x="Classsizepreference", y="GPA", data=df)
filename = "output9.png"
plt.savefig(filename)

# %%
sns.lmplot(x="Participationinsmallclass", y="GPA", data=df)
filename = "output7.png"
plt.savefig(filename)

# %%
sns.lmplot(x="Participationinlargeclass", y="GPA", data=df)
filename = "output8.png"
plt.savefig(filename)

# %%
sns.lmplot(x="Commutetime", y="GPA", data=df)
filename = "output9.png"
plt.savefig(filename)

# %%
sns.jointplot(x="Commutetime", y="GPA", data=df)
filename = "output10.png"
plt.savefig(filename)

# %%
sns.jointplot(x="Participationinsmallclass", y="GPA", data=df)
filename = "output12.png"
plt.savefig(filename)

# %%
sns.jointplot(x="Participationinlargeclass", y="GPA", data=df)
filename = "output11.png"
plt.savefig(filename)

# %%
sns.jointplot(x="Internationalstudenteffect", y="GPA", data=df)
filename = "output13.png"
plt.savefig(filename)
